# %%
# %pip install pillow tqdm
# %pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu113

# %%
# !git clone https://github.com/numediart/Visual-Question-Answering.git
# Out:
# Cloning into 'Visual-Question-Answering'...
# Updating files:  43% (7/16)
# Updating files:  50% (8/16)
# Updating files:  56% (9/16)
# Updating files:  62% (10/16)
# Updating files:  68% (11/16)
# Updating files:  75% (12/16)
# Updating files:  81% (13/16)
# Updating files:  87% (14/16)
# Updating files:  93% (15/16)
# Updating files: 100% (16/16)
# Updating files: 100% (16/16), done.

# %%
cd Visual-Question-Answering/
# Out:
# c:\Users\Vincent\OneDrive - UMONS\Documents\GitHub\Visual-Question-Answering\Visual-Question-Answering

# %%
# !unzip data/data.zip -d data%
import zipfile
zipfile.ZipFile('data/data.zip', 'r').extractall('data/')

# %%
from IPython.display import Image
Image('example.jpg', width=200)

# %%
# %pip install -U git+https://github.com/pytorch/vision
# !python main.py --inference True \
		--ckpt ckpt/model_0.5590.pth \
		--image example.jpg \
		--question "What is the man holding ?"
# Out:
# Collecting git+https://github.com/pytorch/vision
#   Cloning https://github.com/pytorch/vision to c:\users\vincent\appdata\local\temp\pip-req-build-oatqomhz
#   Resolved https://github.com/pytorch/vision to commit 0f971f64f3f8d093d1f2694d2415186e56cb8db4
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/pytorch/vision 'C:\Users\Vincent\AppData\Local\Temp\pip-req-build-oatqomhz'
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [18 lines of output]
#       Traceback (most recent call last):
#         File "c:\Users\Vincent\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 363, in <module>
#           main()
#         File "c:\Users\Vincent\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 345, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#         File "c:\Users\Vincent\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 130, in get_requires_for_build_wheel
#           return hook(config_settings)
#         File "C:\Users\Vincent\AppData\Local\Temp\pip-build-env-3ktbq318\overlay\Lib\site-packages\setuptools\build_meta.py", line 177, in get_requires_for_build_wheel
#           return self._get_build_requires(
#         File "C:\Users\Vincent\AppData\Local\Temp\pip-build-env-3ktbq318\overlay\Lib\site-packages\setuptools\build_meta.py", line 159, in _get_build_requires
#           self.run_setup()
#         File "C:\Users\Vincent\AppData\Local\Temp\pip-build-env-3ktbq318\overlay\Lib\site-packages\setuptools\build_meta.py", line 281, in run_setup
#           super(_BuildMetaLegacyBackend,
#         File "C:\Users\Vincent\AppData\Local\Temp\pip-build-env-3ktbq318\overlay\Lib\site-packages\setuptools\build_meta.py", line 174, in run_setup
#           exec(compile(code, __file__, 'exec'), locals())
#         File "setup.py", line 9, in <module>
#           import torch
#       ModuleNotFoundError: No module named 'torch'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Traceback (most recent call last):
#   File "c:\Users\Vincent\OneDrive - UMONS\Documents\GitHub\Visual-Question-Answering\Visual-Question-Answering\main.py", line 5, in <module>
#     from dataset import Dictionary, VQAFeatureDataset
#   File "c:\Users\Vincent\OneDrive - UMONS\Documents\GitHub\Visual-Question-Answering\Visual-Question-Answering\dataset.py", line 10, in <module>
#     from torchvision import transforms
#   File "c:\Users\Vincent\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\__init__.py", line 2, in <module>
#     from torchvision import datasets
#   File "c:\Users\Vincent\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\datasets\__init__.py", line 9, in <module>
#     from .fakedata import FakeData
#   File "c:\Users\Vincent\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\datasets\fakedata.py", line 3, in <module>
#     from .. import transforms
#   File "c:\Users\Vincent\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\transforms\__init__.py", line 1, in <module>
#     from .transforms import *
#   File "c:\Users\Vincent\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\transforms\transforms.py", line 17, in <module>
#     from . import functional as F
#   File "c:\Users\Vincent\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\transforms\functional.py", line 5, in <module>
#     from PIL import Image, ImageOps, ImageEnhance, PILLOW_VERSION
# ImportError: cannot import name 'PILLOW_VERSION' from 'PIL' (c:\Users\Vincent\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\__init__.py)

# %%
# !python main.py --inference True \
		--ckpt ckpt/model_0.5590.pth \
		--image example.jpg \
		--question "What is the color of the man's hair ?"
# Out:
# Output dir is ckpt
# loading dictionary from data/dictionary.pkl
# Question: What is the color of the man's hair ?
# Answer: brown

# %%
# !python main.py --inference True \
		--ckpt ckpt/model_0.5590.pth \
		--image example.jpg \
		--question "Is the man handsome and smart ?"
# Out:
# Traceback (most recent call last):
#   File "c:\Users\Vincent\OneDrive - UMONS\Documents\GitHub\Visual-Question-Answering\main.py", line 5, in <module>
#     from dataset import Dictionary, VQAFeatureDataset
#   File "c:\Users\Vincent\OneDrive - UMONS\Documents\GitHub\Visual-Question-Answering\dataset.py", line 10, in <module>
#     from torchvision import transforms
#   File "c:\Users\Vincent\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\__init__.py", line 2, in <module>
#     from torchvision import datasets
#   File "c:\Users\Vincent\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\datasets\__init__.py", line 9, in <module>
#     from .fakedata import FakeData
#   File "c:\Users\Vincent\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\datasets\fakedata.py", line 3, in <module>
#     from .. import transforms
#   File "c:\Users\Vincent\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\transforms\__init__.py", line 1, in <module>
#     from .transforms import *
#   File "c:\Users\Vincent\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\transforms\transforms.py", line 17, in <module>
#     from . import functional as F
#   File "c:\Users\Vincent\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\transforms\functional.py", line 5, in <module>
#     from PIL import Image, ImageOps, ImageEnhance, PILLOW_VERSION
# ImportError: cannot import name 'PILLOW_VERSION' from 'PIL' (c:\Users\Vincent\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\__init__.py)
